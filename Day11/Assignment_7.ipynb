# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('testdata.csv')

# %%
df
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %%
#2
df.isna().any()
# Out:
# ord_no          True
# purch_amt      False
# ord_date        True
# customer_id    False
# salesman_id     True
# dtype: bool

# %%
df['ord_no'].isna()
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# Name: ord_no, dtype: bool

# %%
#3
df.isna().sum()
# Out:
# ord_no         4
# purch_amt      0
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %%
df.describe()
# Out:
#              ord_no    purch_amt  customer_id  salesman_id
# count      8.000000    12.000000    12.000000     9.000000
# mean   70006.250000  1461.765000  3001.833333  5002.000000
# std        4.713203  1751.411698     1.029857     0.866025
# min    70001.000000    65.260000  3001.000000  5001.000000
# 25%    70002.750000   140.500000  3001.000000  5001.000000
# 50%    70004.500000   609.575000  3001.500000  5002.000000
# 75%    70010.500000  2420.550000  3002.250000  5003.000000
# max    70013.000000  5760.000000  3004.000000  5003.000000

# %%
df['salesman_id'].mode()
# Out:
# 0    5001.0
# 1    5002.0
# 2    5003.0
# Name: salesman_id, dtype: float64

# %%
df['ord_date'].unique()
# Out:
# array(['2012-10-05', '2012-09-10', nan, '2012-08-17', '2012-07-27',
#        '2012-10-10', '2012-06-27', '2012-04-25'], dtype=object)

# %%
df['ord_date'].mode()
# Out:
# 0    2012-09-10
# Name: ord_date, dtype: object

# %%
df['ord_no'].mode()
# Out:
# 0    70001.0
# 1    70002.0
# 2    70003.0
# 3    70004.0
# 4    70005.0
# 5    70010.0
# 6    70012.0
# 7    70013.0
# Name: ord_no, dtype: float64

# %%
df['ord_no'].fillna(df['ord_no'].mode([0]))
# Out:
# 0     70001.0
# 1     70002.0
# 2     70002.0
# 3     70004.0
# 4     70005.0
# 5     70005.0
# 6     70012.0
# 7     70010.0
# 8     70003.0
# 9     70012.0
# 10        NaN
# 11    70013.0
# Name: ord_no, dtype: float64

# %%
df['ord_no']
# Out:
# 0     70001.0
# 1         NaN
# 2     70002.0
# 3     70004.0
# 4         NaN
# 5     70005.0
# 6         NaN
# 7     70010.0
# 8     70003.0
# 9     70012.0
# 10        NaN
# 11    70013.0
# Name: ord_no, dtype: float64

# %%
#4
df = df.replace({'?' : np.nan,'--':np.nan} )
df
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %%
#5
result = df.dropna(axis=0)

# %%
result
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 5  70005.0    2400.60  2012-07-27         3001       5001.0
# 8  70003.0    2480.40  2012-10-10         3003       5003.0
# 9  70012.0     250.45  2012-06-27         3002       5002.0

# %%
#6
res = df.dropna(axis=1)

# %%
res
# Out:
#     purch_amt  customer_id
# 0      150.50         3002
# 1      270.65         3001
# 2       65.26         3001
# 3      110.50         3003
# 4      948.50         3002
# 5     2400.60         3001
# 6     5760.00         3001
# 7     1983.43         3004
# 8     2480.40         3003
# 9      250.45         3002
# 10      75.29         3001
# 11    3045.60         3001

# %%
#7
all = df.dropna(how='all')

# %%
all
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %%
#8
two = df.dropna(thresh=2)

# %%
two
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %%
#9
col = df.dropna(subset=['ord_no', 'customer_id'])

# %%
col
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %%
#10
valid = df.dropna()

# %%
valid
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 5  70005.0    2400.60  2012-07-27         3001       5001.0
# 8  70003.0    2480.40  2012-10-10         3003       5003.0
# 9  70012.0     250.45  2012-06-27         3002       5002.0

# %%
#11
miss = df.dropna().sum

# %%
miss
# Out:
# <bound method DataFrame.sum of     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 5  70005.0    2400.60  2012-07-27         3001       5001.0
# 8  70003.0    2480.40  2012-10-10         3003       5003.0
# 9  70012.0     250.45  2012-06-27         3002       5002.0>

# %%
miss = df.isna().sum().sum()

# %%
miss
# Out:
# 8

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
#12
result = df['ord_no'].fillna(0)
result
# Out:
# 0     70001.0
# 1         0.0
# 2     70002.0
# 3     70004.0
# 4         0.0
# 5     70005.0
# 6         0.0
# 7     70010.0
# 8     70003.0
# 9     70012.0
# 10        0.0
# 11    70013.0
# Name: ord_no, dtype: float64

# %%
#13
fill = df.fillna(method='bfill')
fill
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1   70002.0     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26  2012-08-17         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003       5002.0
# 4   70005.0     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6   70010.0    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004       5003.0
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10  70013.0      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN

# %%
#13
fill = df.fillna(method='ffill')
fill
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1   70001.0     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26  2012-09-10         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003       5001.0
# 4   70004.0     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6   70005.0    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004       5001.0
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10  70012.0      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001       5003.0

# %%
#14
pamt = df['purch_amt'].fillna(df['purch_amt'].mean())
df['purch_amt'].mean()
# Out:
# 1461.765

# %%
pamt
# Out:
# 0      150.50
# 1      270.65
# 2       65.26
# 3      110.50
# 4      948.50
# 5     2400.60
# 6     5760.00
# 7     1983.43
# 8     2480.40
# 9      250.45
# 10      75.29
# 11    3045.60
# Name: purch_amt, dtype: float64

# %%
#15
inter = df['purch_amt'].interpolate(method='linear',direction='forward')
inter
# Out:
# 0      150.50
# 1      270.65
# 2       65.26
# 3      110.50
# 4      948.50
# 5     2400.60
# 6     5760.00
# 7     1983.43
# 8     2480.40
# 9      250.45
# 10      75.29
# 11    3045.60
# Name: purch_amt, dtype: float64

# %%
#16
miss = df['purch_amt'].isna()

# %%
#17
miss.sum()
# Out:
# 0

# %%
all_miss = df.isna().sum()
all_miss
all_miss.sum()
# Out:
# 8

# %%
#18
miss_index = df.isnull().index

# %%
miss_index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
#19
mode = df.mode()

# %%
mode
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0      65.26  2012-09-10       3001.0       5001.0
# 1   70002.0      75.29         NaN          NaN       5002.0
# 2   70003.0     110.50         NaN          NaN       5003.0
# 3   70004.0     150.50         NaN          NaN          NaN
# 4   70005.0     250.45         NaN          NaN          NaN
# 5   70010.0     270.65         NaN          NaN          NaN
# 6   70012.0     948.50         NaN          NaN          NaN
# 7   70013.0    1983.43         NaN          NaN          NaN
# 8       NaN    2400.60         NaN          NaN          NaN
# 9       NaN    2480.40         NaN          NaN          NaN
# 10      NaN    3045.60         NaN          NaN          NaN
# 11      NaN    5760.00         NaN          NaN          NaN

# %%
mode.iloc[0]
# Out:
# ord_no            70001.0
# purch_amt           65.26
# ord_date       2012-09-10
# customer_id        3001.0
# salesman_id        5001.0
# Name: 0, dtype: object

# %%
df_new = df.fillna(df.mode().iloc[0])

# %%
df_new
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1   70001.0     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26  2012-09-10         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003       5001.0
# 4   70001.0     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6   70001.0    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004       5001.0
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10  70001.0      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001       5001.0

# %%
#20
plt.figure(figsize=(12,6))
sns.heatmap(df.isna(), cbar=False, cmap="YlGnBu")
# Out:
# <Axes: >
