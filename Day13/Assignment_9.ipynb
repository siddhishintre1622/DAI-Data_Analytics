# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', np.nan, 'Eve', 'Frank', 'Grace', np.nan, 'Ivy', 'Jack'],
    'Age': [25, 30, np.nan, 40, 35, np.nan, 29, 33, np.nan, 28],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', np.nan, 'Phoenix', 'Philadelphia', np.nan, 'San Diego', 'Dallas'],
    'Salary': [70000, 80000, np.nan, 60000, 75000, 50000, np.nan, 65000, 70000, 72000],
    'Score': [88, 92, 85, np.nan, 90, 78, 95, 80, np.nan, 86]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name   Age          City   Salary  Score
# 0    Alice  25.0      New York  70000.0   88.0
# 1      Bob  30.0   Los Angeles  80000.0   92.0
# 2  Charlie   NaN       Chicago      NaN   85.0
# 3      NaN  40.0       Houston  60000.0    NaN
# 4      Eve  35.0           NaN  75000.0   90.0
# 5    Frank   NaN       Phoenix  50000.0   78.0
# 6    Grace  29.0  Philadelphia      NaN   95.0
# 7      NaN  33.0           NaN  65000.0   80.0
# 8      Ivy   NaN     San Diego  70000.0    NaN
# 9     Jack  28.0        Dallas  72000.0   86.0

# %%
df['Age']= df['Age'].fillna(df['Age'].mean())

# %%
df
# Out:
#       Name        Age          City   Salary  Score
# 0    Alice  25.000000      New York  70000.0   88.0
# 1      Bob  30.000000   Los Angeles  80000.0   92.0
# 2  Charlie  31.428571       Chicago      NaN   85.0
# 3      NaN  40.000000       Houston  60000.0    NaN
# 4      Eve  35.000000           NaN  75000.0   90.0
# 5    Frank  31.428571       Phoenix  50000.0   78.0
# 6    Grace  29.000000  Philadelphia      NaN   95.0
# 7      NaN  33.000000           NaN  65000.0   80.0
# 8      Ivy  31.428571     San Diego  70000.0    NaN
# 9     Jack  28.000000        Dallas  72000.0   86.0

# %%
df.dropna(subset=['City'])
# Out:
#       Name        Age          City   Salary  Score
# 0    Alice  25.000000      New York  70000.0   88.0
# 1      Bob  30.000000   Los Angeles  80000.0   92.0
# 2  Charlie  31.428571       Chicago      NaN   85.0
# 3      NaN  40.000000       Houston  60000.0    NaN
# 5    Frank  31.428571       Phoenix  50000.0   78.0
# 6    Grace  29.000000  Philadelphia      NaN   95.0
# 8      Ivy  31.428571     San Diego  70000.0    NaN
# 9     Jack  28.000000        Dallas  72000.0   86.0

# %%
df
# Out:
#       Name        Age          City   Salary  Score
# 0    Alice  25.000000      New York  70000.0   88.0
# 1      Bob  30.000000   Los Angeles  80000.0   92.0
# 2  Charlie  31.428571       Chicago      NaN   85.0
# 3      NaN  40.000000       Houston  60000.0    NaN
# 4      Eve  35.000000           NaN  75000.0   90.0
# 5    Frank  31.428571       Phoenix  50000.0   78.0
# 6    Grace  29.000000  Philadelphia      NaN   95.0
# 7      NaN  33.000000           NaN  65000.0   80.0
# 8      Ivy  31.428571     San Diego  70000.0    NaN
# 9     Jack  28.000000        Dallas  72000.0   86.0

# %%
data = {
     'Abilash' : np.random.randint(1,100,10),
     'Ankit': np.random.randint(1,100,10),
     'Ashok' : np.random.randint(1,100,10),
     'Asif' : np.random.randint(1,100,10),
     'Anjaan' : np.random.randint(1,100,10)
}

# %%
data
# Out:
# {'Abilash': array([25, 19, 49, 93,  7, 20, 58, 59, 16, 45]),
#  'Ankit': array([16, 64, 42,  1, 22, 39, 68, 47, 44, 50]),
#  'Ashok': array([32, 46, 79, 96,  2, 73, 73, 99, 56, 26]),
#  'Asif': array([ 7, 12, 12, 65, 31, 88, 17, 98, 93, 26]),
#  'Anjaan': array([97, 52,  3, 81, 98, 15, 80, 70, 61, 26])}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Abilash  Ankit  Ashok  Asif  Anjaan
# 0       25     16     32     7      97
# 1       19     64     46    12      52
# 2       49     42     79    12       3
# 3       93      1     96    65      81
# 4        7     22      2    31      98
# 5       20     39     73    88      15
# 6       58     68     73    17      80
# 7       59     47     99    98      70
# 8       16     44     56    93      61
# 9       45     50     26    26      26

# %%
df['mean'] = df.sum(axis=1)

# %%
df
# Out:
#    Abilash  Ankit  Ashok  Asif  Anjaan  mean
# 0       25     16     32     7      97   177
# 1       19     64     46    12      52   193
# 2       49     42     79    12       3   185
# 3       93      1     96    65      81   336
# 4        7     22      2    31      98   160
# 5       20     39     73    88      15   235
# 6       58     68     73    17      80   296
# 7       59     47     99    98      70   373
# 8       16     44     56    93      61   270
# 9       45     50     26    26      26   173

# %%
grp = df.groupby('mean')

# %%
grp

# %%
df = pd.read_csv('CountryDataIND.csv')

# %%
df.head()
# Out:
#    Series Code Frequency          Series Units of measurement  \
# 0  IT_USE_ii99    Annual  Internet users   Per 100 population
# 1  IT_USE_ii99    Annual  Internet users   Per 100 population
# 2  IT_USE_ii99    Annual  Internet users   Per 100 population
# 3  SE_ADT_1524    Annual   Literacy rate              Percent
# 4  SE_ADT_1524    Annual   Literacy rate              Percent
#
#                  Location        Age group         Sex Reference Area  \
# 0  Total (national level)   All age ranges  Both sexes          India
# 1  Total (national level)   All age ranges  Both sexes          India
# 2  Total (national level)   All age ranges  Both sexes          India
# 3  Total (national level)  15-24 year olds  Both sexes          India
# 4  Total (national level)  15-24 year olds  Both sexes          India
#
#      Source type  Time period  Observation Value Unit multiplier  \
# 0  Not available         1999                0.2           Units
# ...

# %%
df.columns
# Out:
# Index(['Series Code', 'Frequency', 'Series', 'Units of measurement',
#        'Location', 'Age group', 'Sex', 'Reference Area', 'Source type',
#        'Time period', 'Observation Value', 'Unit multiplier',
#        'Nature of data points', 'Time period details', 'Source details',
#        'Footnotes'],
#       dtype='object')

# %%
df.drop('Footnotes',axis=1,inplace=True)

# %%
cols = df.select_dtypes  (include=['int64','float64'])

# %%
cols
# Out:
#     Time period  Observation Value  Time period details
# 0          1999                0.2                 1999
# 1          2002                3.2                 2002
# 2          2006                7.0                 2006
# 3          1991               48.5                 1991
# 4          2001               76.4                 2001
# 5          1992              109.3                 1992
# 6          1998               94.9                 1998
# 7          2005               74.3                 2005
# 8          1992               33.0                 1992
# 9          1998               42.4                 1998
# 10         2005               48.2                 2005
# 11         1997              398.0                 1997
# 12         2000              327.0                 2000
# 13         2002              301.0                 2002
# 14         1990              503.0                 1990
# 15         2000              412.0                 2000
# ...

# %%
cols = cols.columns

# %%
cols
# Out:
# Index(['Time period', 'Observation Value', 'Time period details'], dtype='object')

# %%
for col in cols:
    print(f"Mean of {col}",df[col].mean())
    print(f"median of {col}",df[col].median())
    print("________________________________________")
# Out:
# Mean of Time period 1999.551724137931
# median of Time period 2000.0
# ________________________________________
# Mean of Observation Value 140.80689655172415
# median of Observation Value 48.5
# ________________________________________
# Mean of Time period details 1999.551724137931
# median of Time period details 2000.0
# ________________________________________

# %%
plt.figure(figsize=(8,6))
sns.histplot(x='Observation Value',data=df,bins=10)
# Out:
# <Axes: xlabel='Observation Value', ylabel='Count'>

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Observation Value',y='Time period',data=df)
# Out:
# <Axes: xlabel='Observation Value', ylabel='Time period'>

# %%
#2
df = pd.read_csv('purchase_data.csv')

# %%
df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
df['SN'].count()
# Out:
# 780

# %%
df.index
# Out:
# RangeIndex(start=0, stop=780, step=1)

# %%
df['SN'].unique()
# Out:
# array(['Lisim78', 'Lisovynya38', 'Ithergue48', 'Chamassasya86',
#        'Iskosia90', 'Yalae81', 'Itheria73', 'Iskjaskst81', 'Undjask33',
#        'Chanosian48', 'Inguron55', 'Haisrisuir60', 'Saelaephos52',
#        'Assjaskan73', 'Saesrideu94', 'Lisassa64', 'Lisirra25',
#        'Zontibe81', 'Reunasu60', 'Chamalo71', 'Iathenudil29',
#        'Phiarithdeu40', 'Siarithria38', 'Eyrian71', 'Siala43',
#        'Lisirra87', 'Lirtossa84', 'Eusri44', 'Aela59', 'Tyida79',
#        'Idai61', 'Farusrian86', 'Aeralria27', 'Haillyrgue51', 'Sondim73',
#        'Jeyciman68', 'Idaisuir85', 'Seuthep89', 'Reulae52',
#        'Sondilsaya62', 'Aerithriaphos45', 'Assosia88', 'Aidaillodeu39',
#        'Aelly27', 'Tyeosri53', 'Haerith37', 'Yasrisu92', 'Chanuchi25',
#        'Asur96', 'Iaralrgue74', 'Chanosia34', 'Aelin32', 'Ilosianya35',
#        'Zhisrisu83', 'Phaelap26', 'Raesty92', 'Palyon91', 'Tyisur83',
#        'Yaliru88', 'Yadanu52', 'Jiskimya77', 'Yadaphos40', 'Alo38',
# ...

# %%
df['SN'].nunique()
# Out:
# 576

# %%
df['Item Name'].unique()
# Out:
# array(['Extraction, Quickblade Of Trembling Hands', 'Frenzied Scimitar',
#        'Final Critic', 'Blindscythe', 'Fury', 'Dreamkiss',
#        'Interrogator, Blood Blade of the Queen', 'Abyssal Shard',
#        'Souleater', 'Ghastly Adamantite Protector',
#        'Singed Onyx Warscythe', 'Renewed Skeletal Katana',
#        "Bloodlord's Fetish", 'Bone Crushing Silver Skewer',
#        'Deadline, Voice Of Subtlety', 'Second Chance', 'Devine',
#        'Nirvana', 'Blazefury, Protector of Delusions',
#        'Despair, Favor of Due Diligence',
#        'Sun Strike, Jaws of Twisted Visions', 'Warped Fetish',
#        'Severance', 'Persuasion',
#        'Oathbreaker, Last Hope of the Breaking Storm', 'Demise',
#        'Blood-Forged Skeletal Spine',
#        'Stormbringer, Dark Blade of Ending Misery',
#        'Shadow Strike, Glory of Ending Hope', 'Striker',
#        'Wolf, Promise of the Moonwalker', "Faith's Scimitar",
# ...

# %%
df['Item Name'].nunique()
# Out:
# 179

# %%
df['Price'].mean()
# Out:
# 3.0509871794871795

# %%
df['Purchase ID'].count()
# Out:
# 780

# %%
df['Price'].sum()
# Out:
# 2379.77

# %%
df['Gender']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 775    Female
# 776      Male
# 777      Male
# 778      Male
# 779      Male
# Name: Gender, Length: 780, dtype: object

# %%
male = df[df['Gender'] == 'Male']

# %%
male
# Out:
#      Purchase ID             SN  Age Gender  Item ID  \
# 0              0        Lisim78   20   Male      108
# 1              1    Lisovynya38   40   Male      143
# 2              2     Ithergue48   24   Male       92
# 3              3  Chamassasya86   24   Male      100
# 4              4      Iskosia90   23   Male      131
# ..           ...            ...  ...    ...      ...
# 774          774     Jiskjask80   11   Male      101
# 776          776         Iral74   21   Male      164
# 777          777     Yathecal72   20   Male       67
# 778          778        Sisur91    7   Male      101
# 779          779      Ennrian78   24   Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
male_count,c = male.shape

# %%
male_count
# Out:
# 652

# %%
female = df[df['Gender'] == 'Female']

# %%
female
# Out:
#      Purchase ID               SN  Age  Gender  Item ID  \
# 15            15        Lisassa64   21  Female       98
# 18            18        Reunasu60   22  Female       82
# 38            38         Reulae52   10  Female      116
# 41            41        Assosia88   20  Female        7
# 55            55        Phaelap26   25  Female       84
# ..           ...              ...  ...     ...      ...
# 731          731         Eudanu84   22  Female       12
# 740          740        Reunasu60   22  Female      127
# 754          754  Pheosurllorin41   23  Female       79
# 767          767          Ilmol66    8  Female       92
# 775          775       Aethedru70   21  Female       60
#
#                         Item Name  Price
# 15    Deadline, Voice Of Subtlety   2.89
# 18                        Nirvana   4.90
# 38        Renewed Skeletal Katana   4.18
# 41   Thorn, Satchel of Dark Souls   1.33
# 55                     Arcane Gem   3.79
# ...

# %%
female_count,c = female.shape

# %%
female_count
# Out:
# 113

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Other / Non-Disclosed', 'Female'], dtype=object)

# %%
other =  df[df['Gender'] == 'Other / Non-Disclosed']

# %%
other
# Out:
#      Purchase ID            SN  Age                 Gender  Item ID  \
# 9              9   Chanosian48   35  Other / Non-Disclosed      136
# 22            22  Siarithria38   38  Other / Non-Disclosed       24
# 82            82    Haerithp41   16  Other / Non-Disclosed      160
# 111          111      Sundim98   21  Other / Non-Disclosed       41
# 228          228   Jiskirran77   20  Other / Non-Disclosed       80
# 237          237     Idairin51   20  Other / Non-Disclosed       16
# 242          242     Eodaisu60   16  Other / Non-Disclosed       39
# 291          291     Idairin51   20  Other / Non-Disclosed       35
# 350          350     Rairith81   15  Other / Non-Disclosed       34
# 401          401      Lirtim36   15  Other / Non-Disclosed       46
# 484          484   Chanosian48   35  Other / Non-Disclosed       39
# 549          549    Maluncil97   25  Other / Non-Disclosed      146
# 629          629    Maluncil97   25  Other / Non-Disclosed      107
# ...

# %%
other_count,c = other.shape

# %%
other_count
# Out:
# 15

# %%
print("Male count",male_count)
print("Female count",female_count)
print("Other count",other_count)
# Out:
# Male count 652
# Female count 113
# Other count 15

# %%
total_count = male_count + female_count + other_count
total_count
# Out:
# 780

# %%
male_percent = male_count*100/total_count

# %%
female_percent = female_count*100/total_count

# %%
other_percent = other_count*100/total_count

# %%
print("Male count",male_count)
print("Female count",female_count)
print("Other count",other_count)
print("_____________________________________")
print("Male Percentage : {:.2f} ".format(male_percent))
print("Feale Percentage : {:.2f}".format(female_percent))
print("Other Percentage : {:.2f}".format(other_percent))
# Out:
# Male count 652
# Female count 113
# Other count 15
# _____________________________________
# Male Percentage : 83.59
# Feale Percentage : 14.49
# Other Percentage : 1.92

# %%
group_by_gender = df.groupby('Gender')

# %%
group_by_gender

# %%
group_by_gender['Purchase ID'].sum()
# Out:
# Gender
# Female                    42870
# Male                     255921
# Other / Non-Disclosed      5019
# Name: Purchase ID, dtype: int64

# %%
group_by_gender['Price'].mean()
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# Name: Price, dtype: float64

# %%
group_by_gender['Price'].sum()
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
ten = df[df['Age']<10]

# %%
ten
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 27            27        Eusri44    7    Male       96
# 33            33   Haillyrgue51    7    Male       44
# 37            37      Seuthep89    8    Male       73
# 78            78   Haillyrgue51    7    Male       50
# 81            81       Heudai45    8  Female      174
# 187          187     Tyeurith29    8    Male       11
# 272          272   Anallorgue57    8    Male      133
# 311          311   Anallorgue57    8    Male       71
# 339          339        Ilmol66    8  Female      124
# 446          446   Chanossast57    7  Female      119
# 481          481     Sondossa69    7    Male      179
# 486          486   Eurithphos97    9    Male       53
# 515          515   Haillyrgue51    7    Male       40
# 546          546     Sondadar26    9    Male      159
# 575          575     Sondadar26    9    Male      137
# 610          610  Frichossala54    7    Male      159
# ...

# %%
ten_fourteen = df[(df['Age']>=10) & (df['Age']<=14)]

# %%
ten_fourteen
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 26            26     Lirtossa84   11    Male       71
# 32            32     Aeralria27   10    Male      133
# 38            38       Reulae52   10  Female      116
# 54            54     Zhisrisu83   10    Male       25
# 56            56       Raesty92   12    Male      108
# 76            76   Mindadaran26   13  Female       88
# 139          139       Lisasi93   13    Male      158
# 141          141     Zhisrisu83   10    Male       60
# 155          155     Aillyrin83   10  Female       98
# 163          163        Sidap51   11    Male       65
# 292          292       Lisasi93   13    Male       70
# 299          299     Lirtossa84   11    Male      164
# 394          394  Lassassasda30   12    Male       60
# 408          408       Raesty92   12    Male       53
# 411          411       Lisico81   10    Male      101
# 413          413        Siana77   12    Male       93
# ...

# %%
ten.shape
# Out:
# (23, 7)

# %%
fifteen_nineteen = df[(df['Age'] >=15) & (df['Age'] <=19)]

# %%
fifteen_nineteen
# Out:
#      Purchase ID             SN  Age Gender  Item ID  \
# 30            30         Idai61   19   Male      140
# 34            34       Sondim73   19   Male      160
# 42            42  Aidaillodeu39   18   Male       72
# 59            59       Yaliru88   19   Male      105
# 61            61     Jiskimya77   17   Male      178
# ..           ...            ...  ...    ...      ...
# 757          757      Eratiel90   18   Male       57
# 764          764   Saedaiphos46   18   Male      113
# 765          765        Irith83   18   Male      130
# 769          769      Ilosian36   15   Male      145
# 771          771   Iskossasda43   16   Male       25
#
#                                         Item Name  Price
# 30                                        Striker   2.94
# 34                                     Azurewrath   4.40
# 42                                  Winter's Bite   3.77
# 59                   Hailstorm Shadowsteel Scythe   3.03
# ...

# %%
nineteen = df[df['Age'] > 19]

# %%
nineteen
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 773          773         Hala31   21    Male       19
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
ten
ten_fourteen
fifteen_nineteen
nineteen
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 773          773         Hala31   21    Male       19
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
ten['Purchase ID'].count()
# Out:
# 23

# %%
ten['Price'].mean()
# Out:
# 3.353478260869565

# %%
ten['Price'].sum()
# Out:
# 77.13

# %%
ten_fourteen['Price'].count()
# Out:
# 28

# %%
ten_fourteen['Price'].mean()
# Out:
# 2.9564285714285714

# %%
ten_fourteen['Price'].sum()
# Out:
# 82.78

# %%
fifteen_nineteen['Price'].count()
# Out:
# 136

# %%
fifteen_nineteen['Price'].mean()
# Out:
# 3.035955882352941

# %%
fifteen_nineteen['Price'].sum()
# Out:
# 412.89

# %%
nineteen['Price'].count()
# Out:
# 593

# %%
nineteen['Price'].mean()
# Out:
# 3.04716694772344

# %%
nineteen['Price'].sum()
# Out:
# 1806.97

# %%
df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
asc = df.sort_values(by='Price',ascending=False)

# %%
asc
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 554          554       Dyally87   22    Male       63
# 189          189       Hiasri33   23    Male       63
# 110          110        Ririp86   25    Male      139
# 246          246     Lirtilsa71   24    Male      139
# 493          493  Chanirrasta87   14    Male      139
# ..           ...            ...  ...     ...      ...
# 586          586     Chanirra79   23  Female      155
# 282          282        Aidai61   21    Male      155
# 371          371     Eusurdeu49   23    Male      155
# 63            63          Alo38   20    Male      125
# 418          418        Marim28   25  Female      125
#
#                       Item Name  Price
# 554              Stormfury Mace   4.99
# 189              Stormfury Mace   4.99
# 110     Mercy, Katana of Dismay   4.94
# 246     Mercy, Katana of Dismay   4.94
# 493     Mercy, Katana of Dismay   4.94
# ..                          ...    ...
# ...

# %%
top_5 = asc.head()

# %%
top_5
# Out:
#      Purchase ID             SN  Age Gender  Item ID                Item Name  \
# 554          554       Dyally87   22   Male       63           Stormfury Mace
# 189          189       Hiasri33   23   Male       63           Stormfury Mace
# 110          110        Ririp86   25   Male      139  Mercy, Katana of Dismay
# 246          246     Lirtilsa71   24   Male      139  Mercy, Katana of Dismay
# 493          493  Chanirrasta87   14   Male      139  Mercy, Katana of Dismay
#
#      Price
# 554   4.99
# 189   4.99
# 110   4.94
# 246   4.94
# 493   4.94

# %%
df.groupby(['Gender','SN'])['Price'].mean()
# Out:
# Gender                 SN
# Female                 Adastirin33      4.480
#                        Aerithllora36    4.320
#                        Aethedru70       3.540
#                        Aidain51         3.450
#                        Aiduesu86        4.480
#                                         ...
# Other / Non-Disclosed  Lirtim36         1.330
#                        Maluncil97       2.640
#                        Rairith81        2.220
#                        Siarithria38     3.455
#                        Sundim98         4.750
# Name: Price, Length: 576, dtype: float64

# %%
df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
item = df['Item Name'].nunique()

# %%
item
# Out:
# 179

# %%
group_by_item = df.groupby('Item Name')

# %%
group_by_item

# %%
group_by_item.head()
# Out:
#      Purchase ID             SN  Age Gender  Item ID  \
# 0              0        Lisim78   20   Male      108
# 1              1    Lisovynya38   40   Male      143
# 2              2     Ithergue48   24   Male       92
# 3              3  Chamassasya86   24   Male      100
# 4              4      Iskosia90   23   Male      131
# ..           ...            ...  ...    ...      ...
# 764          764   Saedaiphos46   18   Male      113
# 765          765        Irith83   18   Male      130
# 766          766   Aelastirin39   23   Male       58
# 777          777     Yathecal72   20   Male       67
# 779          779      Ennrian78   24   Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %%
df['Item Name'].value_counts()
# Out:
# Item Name
# Final Critic                                    13
# Oathbreaker, Last Hope of the Breaking Storm    12
# Extraction, Quickblade Of Trembling Hands        9
# Nirvana                                          9
# Fiery Glass Crusader                             9
#                                                 ..
# Exiled Mithril Longsword                         1
# Undead Crusader                                  1
# Celeste                                          1
# Ghost Reaver, Longsword of Magic                 1
# Gladiator's Glaive                               1
# Name: count, Length: 179, dtype: int64

# %%
df['SN'].nunique()
# Out:
# 576

# %%
#6
top_5_spenders  =df.groupby('SN')['Price'].sum().sort_values(ascending = False).head(5)

# %%
top_5_spenders
# Out:
# SN
# Lisosia93      18.96
# Idastidru52    15.45
# Chamjask73     13.83
# Iral74         13.62
# Iskadarya95    13.10
# Name: Price, dtype: float64

# %%
#7
most_popular_item= df.groupby(['Item Name','Item ID'])['Purchase ID'].count().sort_values(ascending = False).head(5)
most_popular_item
# Out:
# Item Name                                     Item ID
# Oathbreaker, Last Hope of the Breaking Storm  178        12
# Extraction, Quickblade Of Trembling Hands     108         9
# Nirvana                                       82          9
# Fiery Glass Crusader                          145         9
# Pursuit, Cudgel of Necromancy                 19          8
# Name: Purchase ID, dtype: int64

# %%
#8
most_profitable_item= df.groupby(['Item Name', 'Price'])['Price'].sum().sort_values(ascending= False).head()
most_profitable_item
# Out:
# Item Name                                     Price
# Oathbreaker, Last Hope of the Breaking Storm  4.23     50.76
# Nirvana                                       4.90     44.10
# Fiery Glass Crusader                          4.58     41.22
# Final Critic                                  4.88     39.04
# Singed Scalpel                                4.35     34.80
# Name: Price, dtype: float64

# %%
df= pd.read_csv('all_alpha_08.csv')
df
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...    ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
# ...

# %%
df.dropna()
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...    ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
# ...

# %%
df.head()
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    Underhood ID    Veh Class Air Pollution Score FE Calc Appr City MPG  \
# 0  8HNXT03.7PKR          SUV                   7          Drv       15
# 1  8HNXT03.7PKR          SUV                   6          Drv       15
# 2  8HNXT02.3DKR          SUV                   7          Drv       17
# 3  8HNXT02.3DKR          SUV                   6          Drv       17
# 4  8HNXV03.5HKR  midsize car                   7          Drv       16
#
#   Hwy MPG Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# ...

# %%
df.fillna(0)
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...    ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
# ...

# %%
df.drop_duplicates(subset=['Drive'])
# Out:
#                       Model  Displ      Cyl    Trans Drive      Fuel  \
# 0                 ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline
# 6                  ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline
# 389  CHEVROLET Express 3500    6.0      NaN      NaN   NaN  Gasoline
#
#     Sales Area Stnd  Underhood ID    Veh Class Air Pollution Score  \
# 0           CA   U2  8HNXT03.7PKR          SUV                   7
# 6           CA   U2  8HNXV03.5HKR  midsize car                   7
# 389         FC   B8  8GMXT06.2394          van                   3
#
#     FE Calc Appr City MPG Hwy MPG Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score  \
# 0            Drv       15      20      17        22.0527                    4
# 6            Drv       18      26      21        27.2768                    6
# 389          NaN      NaN     NaN     NaN            NaN                  NaN
#
#     SmartWay
# 0         no
# 6        yes
# 389       no

# %%
df.shape
# Out:
# (2404, 18)

# %%
df.sort_values(by= 'Air Pollution Score', ascending= False)
# Out:
#                                Model  Displ      Cyl    Trans Drive      Fuel  \
# 1829                      PONTIAC G5    2.2  (4 cyl)    Man-5   2WD  Gasoline
# 816               FORD Escape Hybrid    2.3  (4 cyl)  Auto-AV   4WD  Gasoline
# 2187                    TOYOTA Prius    1.5  (4 cyl)  Auto-AV   2WD  Gasoline
# 1665                   MERCURY Sable    3.5  (6 cyl)  Auto-L6   4WD  Gasoline
# 1666                   MERCURY Sable    3.5  (6 cyl)  Auto-L6   2WD  Gasoline
# ...                              ...    ...      ...      ...   ...       ...
# 899                        FORD F350    6.8      NaN      NaN   4WD  Gasoline
# 1591  MERCEDES-BENZ ML320 CDI 4Matic    3.0  (6 cyl)  Auto-L7   4WD    diesel
# 748                   DODGE RAM 3500    5.7      NaN      NaN   2WD  Gasoline
# 749                   DODGE RAM 3500    5.7      NaN      NaN   4WD  Gasoline
# 750                   DODGE RAM 3500    5.7      NaN      NaN   NaN  Gasoline
#
# ...

# %%
df.rename(columns= {'Displ':'Display'})
# Out:
#             Model  Display      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0       ACURA MDX      3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX      3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX      2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX      2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL      3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...      ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90      3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90      4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90      3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90      3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90      4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
# ...

# %%
df.isnull()
# Out:
#       Model  Displ    Cyl  Trans  Drive   Fuel  Sales Area   Stnd  \
# 0     False  False  False  False  False  False       False  False
# 1     False  False  False  False  False  False       False  False
# 2     False  False  False  False  False  False       False  False
# 3     False  False  False  False  False  False       False  False
# 4     False  False  False  False  False  False       False  False
# ...     ...    ...    ...    ...    ...    ...         ...    ...
# 2399  False  False  False  False  False  False       False  False
# 2400  False  False  False  False  False  False       False  False
# 2401  False  False  False  False  False  False       False  False
# 2402  False  False  False  False  False  False       False  False
# 2403  False  False  False  False  False  False       False  False
#
#       Underhood ID  Veh Class  Air Pollution Score  FE Calc Appr  City MPG  \
# 0            False      False                False         False     False
# ...

# %%
df.isnull().sum()
# Out:
# Model                     0
# Displ                     0
# Cyl                     199
# Trans                   199
# Drive                    93
# Fuel                      0
# Sales Area                0
# Stnd                      0
# Underhood ID              0
# Veh Class                 0
# Air Pollution Score       0
# FE Calc Appr            199
# City MPG                199
# Hwy MPG                 199
# Cmb MPG                 199
# Unadj Cmb MPG           199
# Greenhouse Gas Score    199
# SmartWay                  0
# dtype: int64

# %%
df.head(2)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
#
#    Underhood ID Veh Class Air Pollution Score FE Calc Appr City MPG Hwy MPG  \
# 0  8HNXT03.7PKR       SUV                   7          Drv       15      20
# 1  8HNXT03.7PKR       SUV                   6          Drv       15      20
#
#   Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# 0      17        22.0527                    4       no
# 1      17        22.0527                    4       no

# %%
df['Displ']= df['Displ'].astype(float)

# %%
df['Displ'].dtypes
# Out:
# dtype('float64')

# %%
df['Veh Class']=df['Veh Class'].str.lower()

# %%
df.head(2)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
#
#    Underhood ID Veh Class Air Pollution Score FE Calc Appr City MPG Hwy MPG  \
# 0  8HNXT03.7PKR       suv                   7          Drv       15      20
# 1  8HNXT03.7PKR       suv                   6          Drv       15      20
#
#   Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# 0      17        22.0527                    4       no
# 1      17        22.0527                    4       no

# %%
df['Model']= df['Model'].str.strip()

# %%
df.head(2)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
#
#    Underhood ID Veh Class Air Pollution Score FE Calc Appr City MPG Hwy MPG  \
# 0  8HNXT03.7PKR       suv                   7          Drv       15      20
# 1  8HNXT03.7PKR       suv                   6          Drv       15      20
#
#   Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# 0      17        22.0527                    4       no
# 1      17        22.0527                    4       no

# %%
df.describe()
# Out:
#              Displ  Unadj Cmb MPG
# count  2404.000000    2205.000000
# mean      3.748918      23.916104
# std       1.335785       6.366170
# min       1.300000      10.018400
# 25%       2.500000      19.113900
# 50%       3.500000      23.921300
# 75%       4.800000      27.869300
# max       8.400000      65.777800

# %%
df['Fuel'].unique()
# Out:
# array(['Gasoline', 'ethanol/gas', 'ethanol', 'diesel', 'CNG'],
#       dtype=object)

# %%
df.tail()
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
#       Underhood ID Veh Class Air Pollution Score FE Calc Appr City MPG  \
# 2399  8VVXB03.2U2N       suv                   7          Drv       14
# 2400  8VVXB04.4U2N       suv                   7          Drv       13
# 2401  8VVXB03.2U2N       suv                   6          Drv       14
# 2402  8VVXB03.2U2N       suv                   6          Drv       14
# 2403  8VVXB04.4U2N       suv                   6          Drv       13
#
#      Hwy MPG Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# ...

# %%
df.describe()
# Out:
#              Displ  Unadj Cmb MPG
# count  2404.000000    2205.000000
# mean      3.748918      23.916104
# std       1.335785       6.366170
# min       1.300000      10.018400
# 25%       2.500000      19.113900
# 50%       3.500000      23.921300
# 75%       4.800000      27.869300
# max       8.400000      65.777800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2404 entries, 0 to 2403
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 2404 non-null   object
#  1   Displ                 2404 non-null   float64
#  2   Cyl                   2205 non-null   object
#  3   Trans                 2205 non-null   object
#  4   Drive                 2311 non-null   object
#  5   Fuel                  2404 non-null   object
#  6   Sales Area            2404 non-null   object
#  7   Stnd                  2404 non-null   object
#  8   Underhood ID          2404 non-null   object
#  9   Veh Class             2404 non-null   object
#  10  Air Pollution Score   2404 non-null   object
#  11  FE Calc Appr          2205 non-null   object
#  12  City MPG              2205 non-null   object
#  13  Hwy MPG               2205 non-null   object
#  14  Cmb MPG               2205 non-null   object
# ...

# %%
df.head()
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    Underhood ID    Veh Class Air Pollution Score FE Calc Appr City MPG  \
# 0  8HNXT03.7PKR          suv                   7          Drv       15
# 1  8HNXT03.7PKR          suv                   6          Drv       15
# 2  8HNXT02.3DKR          suv                   7          Drv       17
# 3  8HNXT02.3DKR          suv                   6          Drv       17
# 4  8HNXV03.5HKR  midsize car                   7          Drv       16
#
#   Hwy MPG Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# ...

# %%
df2= pd.read_csv('all_alpha_18.csv')
df2
# Out:
#             Model  Displ  Cyl       Trans Drive                  Fuel  \
# 0       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 2       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1606  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1608  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert Region       Stnd            Stnd Description  Underhood ID  \
# ...

# %%
df['Fuel'].unique()
# Out:
# array(['Gasoline', 'ethanol/gas', 'ethanol', 'diesel', 'CNG'],
#       dtype=object)

# %%
df['Fuel'].value_counts()
# Out:
# Fuel
# Gasoline       2318
# ethanol/gas      72
# diesel           11
# CNG               2
# ethanol           1
# Name: count, dtype: int64

# %%
df2['Fuel'].value_counts()
# Out:
# Fuel
# Gasoline                1492
# Ethanol/Gas               55
# Diesel                    38
# Gasoline/Electricity      24
# Electricity                2
# Name: count, dtype: int64

# %%
print("The alternative sources of fuel available in 2008 & 2018 are'CNG', 'ethanol', 'gasoline' and 'Electricity'.")
# Out:
# The alternative sources of fuel available in 2008 & 2018 are'CNG', 'ethanol', 'gasoline' and 'Electricity'.

# %%
# Out:
# Fuel
# Gasoline                1492
# Ethanol/Gas               55
# Diesel                    38
# Gasoline/Electricity      24
# Electricity                2
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
#
#    Underhood ID Veh Class Air Pollution Score FE Calc Appr City MPG Hwy MPG  \
# 0  8HNXT03.7PKR       suv                   7          Drv       15      20
# 1  8HNXT03.7PKR       suv                   6          Drv       15      20
#
#   Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# 0      17        22.0527                    4       no
# 1      17        22.0527                    4       no

# %% [markdown]
# Using clean08 and clean18 dataset
# Q2 to Q4

# %%
df=pd.read_csv("clean_08.csv")

# %%
df.head()
# Out:
#        model  displ  cyl    trans drive      fuel    veh_class  \
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          SUV
# 1  ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          SUV
# 2   ACURA RL    3.5    6  Auto-S5   4WD  Gasoline  midsize car
# 3   ACURA TL    3.2    6  Auto-S5   2WD  Gasoline  midsize car
# 4   ACURA TL    3.5    6  Auto-S5   2WD  Gasoline  midsize car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 0                  7.0      15.0     20.0     17.0                     4
# 1                  7.0      17.0     22.0     19.0                     5
# 2                  7.0      16.0     24.0     19.0                     5
# 3                  7.0      18.0     26.0     21.0                     6
# 4                  7.0      17.0     26.0     20.0                     6
#
#   smartway
# 0       no
# 1       no
# 2       no
# 3      yes
# 4      yes

# %%
df2=pd.read_csv("clean_18.csv")

# %%
df2.head()
# Out:
#        model  displ  cyl       trans drive      fuel  veh_class  \
# 0  ACURA RDX    3.5    6  SemiAuto-6   2WD  Gasoline  small SUV
# 1  ACURA RDX    3.5    6  SemiAuto-6   4WD  Gasoline  small SUV
# 2  ACURA TLX    2.4    4       AMS-8   2WD  Gasoline  small car
# 3  ACURA TLX    3.5    6  SemiAuto-9   2WD  Gasoline  small car
# 4  ACURA TLX    3.5    6  SemiAuto-9   4WD  Gasoline  small car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 0                  3.0      20.0     28.0     23.0                     5
# 1                  3.0      19.0     27.0     22.0                     4
# 2                  3.0      23.0     33.0     27.0                     6
# 3                  3.0      20.0     32.0     24.0                     5
# 4                  3.0      21.0     30.0     24.0                     5
#
#   smartway
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No

# %%
df.groupby('veh_class')['cmb_mpg'].mean().plot.bar()
# Out:
# <Axes: xlabel='veh_class'>

# %%
df['smartway'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df2['smartway'].unique()
# Out:
# array(['No', 'Yes', 'Elite'], dtype=object)

# %%
df = df.select_dtypes(include=['number'])

# %%
df
# Out:
#      displ  cyl  air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  \
# 0      3.7    6                  7.0      15.0     20.0     17.0
# 1      2.3    4                  7.0      17.0     22.0     19.0
# 2      3.5    6                  7.0      16.0     24.0     19.0
# 3      3.2    6                  7.0      18.0     26.0     21.0
# 4      3.5    6                  7.0      17.0     26.0     20.0
# ..     ...  ...                  ...       ...      ...      ...
# 982    3.2    6                  7.0      14.0     20.0     16.0
# 983    3.2    6                  7.0      14.0     20.0     16.0
# 984    4.4    8                  7.0      13.0     19.0     15.0
# 985    3.0    6                  6.0      13.0     19.0     15.0
# 986    3.0    6                  4.0      18.0     25.0     21.0
#
#      greenhouse_gas_score
# 0                       4
# 1                       5
# 2                       5
# 3                       6
# 4                       6
# ...

# %%
corr = df.corr()

# %%
corr
# Out:
#                          displ       cyl  air_pollution_score  city_mpg  \
# displ                 1.000000  0.899304            -0.289993 -0.790440
# cyl                   0.899304  1.000000            -0.270417 -0.756304
# air_pollution_score  -0.289993 -0.270417             1.000000  0.432434
# city_mpg             -0.790440 -0.756304             0.432434  1.000000
# hwy_mpg              -0.801678 -0.733064             0.400708  0.902942
# cmb_mpg              -0.818799 -0.770538             0.425784  0.980891
# greenhouse_gas_score -0.847613 -0.820940             0.388444  0.910693
#
#                        hwy_mpg   cmb_mpg  greenhouse_gas_score
# displ                -0.801678 -0.818799             -0.847613
# cyl                  -0.733064 -0.770538             -0.820940
# air_pollution_score   0.400708  0.425784              0.388444
# city_mpg              0.902942  0.980891              0.910693
# hwy_mpg               1.000000  0.960533              0.931744
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(corr,annot = True,cmap='coolwarm',fmt='.2f')
# Out:
# <Axes: >
