# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('diamonds.csv')

# %%
df.head(6)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
#
#       y     z
# 0  3.98  2.43
# 1  3.84  2.31
# 2  4.07  2.31
# 3  4.23  2.63
# 4  4.35  2.75
# 5  3.96  2.48

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df=df.drop(columns='Unnamed: 0')

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df_new = df[['carat','cut','x','y','z']]

# %%
df_new.head(6)
# Out:
#    carat        cut     x     y     z
# 0   0.23      Ideal  3.95  3.98  2.43
# 1   0.21    Premium  3.89  3.84  2.31
# 2   0.23       Good  4.05  4.07  2.31
# 3   0.29    Premium  4.20  4.23  2.63
# 4   0.31       Good  4.34  4.35  2.75
# 5   0.24  Very Good  3.94  3.96  2.48

# %%
df['carat']
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
ser = pd.DataFrame(df['carat'])

# %%
ser
# Out:
#        carat
# 0       0.23
# 1       0.21
# 2       0.23
# 3       0.29
# 4       0.31
# ...      ...
# 53935   0.72
# 53936   0.72
# 53937   0.70
# 53938   0.86
# 53939   0.75
#
# [53940 rows x 1 columns]

# %%
df_new['quality_color'] = df['color']
# Out:
# C:\Users\dai.STUDENTSDC\AppData\Local\Temp\ipykernel_8056\2217048739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['quality_color'] = df['color']

# %%
df_new.head()
# Out:
#    carat      cut     x     y     z quality_color
# 0   0.23    Ideal  3.95  3.98  2.43             E
# 1   0.21  Premium  3.89  3.84  2.31             E
# 2   0.23     Good  4.05  4.07  2.31             E
# 3   0.29  Premium  4.20  4.23  2.63             I
# 4   0.31     Good  4.34  4.35  2.75             J

# %%
df_new.columns
# Out:
# Index(['carat', 'cut', 'x', 'y', 'z', 'quality_color'], dtype='object')

# %%
df_new.count()
# Out:
# carat            53940
# cut              53940
# x                53940
# y                53940
# z                53940
# quality_color    53940
# dtype: int64

# %%
df_new.size
# Out:
# 323640

# %%
df_new.shape
# Out:
# (53940, 6)

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
df.describe(include=object)
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.rename(columns={'x':'X','carat':'Carat','cut':'Cut','color':'Color','clarity':'Clarity','depth':'Depth','table':'Table','price':'Price','y':'Y','z':'Z','quality color':'Quality Color'},inplace=True)

# %%
df
# Out:
#        Carat        Cut Color Clarity  Depth  Table  Price     X     Y     Z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df = df.drop(['Z'],axis=1)
df
# Out:
#        Carat        Cut Color Clarity  Depth  Table  Price     X     Y
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
# [53940 rows x 9 columns]

# %%
df = df.drop(['X','Y'],axis=1)
df
# Out:
#        Carat        Cut Color Clarity  Depth  Table  Price
# 0       0.23      Ideal     E     SI2   61.5   55.0    326
# 1       0.21    Premium     E     SI1   59.8   61.0    326
# 2       0.23       Good     E     VS1   56.9   65.0    327
# 3       0.29    Premium     I     VS2   62.4   58.0    334
# 4       0.31       Good     J     SI2   63.3   58.0    335
# ...      ...        ...   ...     ...    ...    ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757
# 53936   0.72       Good     D     SI1   63.1   55.0   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757
#
# [53940 rows x 7 columns]

# %%
df.drop(df.index[:10])
# Out:
#        Carat        Cut Color Clarity  Depth  Table  Price
# 10      0.30       Good     J     SI1   64.0   55.0    339
# 11      0.23      Ideal     J     VS1   62.8   56.0    340
# 12      0.22    Premium     F     SI1   60.4   61.0    342
# 13      0.31      Ideal     J     SI2   62.2   54.0    344
# 14      0.20    Premium     E     SI2   60.2   62.0    345
# ...      ...        ...   ...     ...    ...    ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757
# 53936   0.72       Good     D     SI1   63.1   55.0   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757
#
# [53930 rows x 7 columns]

# %%
df.drop([2,4,5,8,9])
# Out:
#        Carat        Cut Color Clarity  Depth  Table  Price
# 0       0.23      Ideal     E     SI2   61.5   55.0    326
# 1       0.21    Premium     E     SI1   59.8   61.0    326
# 3       0.29    Premium     I     VS2   62.4   58.0    334
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336
# 7       0.26  Very Good     H     SI1   61.9   55.0    337
# ...      ...        ...   ...     ...    ...    ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757
# 53936   0.72       Good     D     SI1   63.1   55.0   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757
#
# [53935 rows x 7 columns]

# %%
df.sort_values(by=['Cut'], ascending=True)
# Out:
#        Carat        Cut Color Clarity  Depth  Table  Price
# 3850    1.01       Fair     F     SI2   64.8   55.0   3477
# 51464   1.20       Fair     G      I1   66.6   57.0   2376
# 51466   0.90       Fair     G     SI2   65.4   57.0   2376
# 10237   1.26       Fair     D     SI2   64.5   59.0   4746
# 10760   1.01       Fair     E     SI1   69.5   55.0   4853
# ...      ...        ...   ...     ...    ...    ...    ...
# 7402    0.33  Very Good     G     VS2   62.8   54.0    579
# 43101   0.57  Very Good     E     SI2   58.8   57.3   1384
# 16893   1.00  Very Good     G     VS2   62.2   58.0   6743
# 16898   1.00  Very Good     D     VS2   59.6   60.0   6745
# 21164   1.00  Very Good     E    VVS2   61.7   55.0   9324
#
# [53940 rows x 7 columns]

# %%
df['Cut'].sort_values(ascending=True)
# Out:
# 3850          Fair
# 51464         Fair
# 51466         Fair
# 10237         Fair
# 10760         Fair
#            ...
# 7402     Very Good
# 43101    Very Good
# 16893    Very Good
# 16898    Very Good
# 21164    Very Good
# Name: Cut, Length: 53940, dtype: object

# %%
df.sort_values(by=['Price'], ascending=False)
# Out:
#        Carat        Cut Color Clarity  Depth  Table  Price
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803
# ...      ...        ...   ...     ...    ...    ...    ...
# 4       0.31       Good     J     SI2   63.3   58.0    335
# 3       0.29    Premium     I     VS2   62.4   58.0    334
# 2       0.23       Good     E     VS1   56.9   65.0    327
# 1       0.21    Premium     E     SI1   59.8   61.0    326
# 0       0.23      Ideal     E     SI2   61.5   55.0    326
#
# [53940 rows x 7 columns]

# %%
df['Price'].sort_values(ascending=False)
# Out:
# 27749    18823
# 27748    18818
# 27747    18806
# 27746    18804
# 27745    18803
#          ...
# 4          335
# 3          334
# 2          327
# 1          326
# 0          326
# Name: Price, Length: 53940, dtype: int64

# %%
df.sort_values(by= ['Carat'] , ascending=True)
# Out:
#        Carat      Cut Color Clarity  Depth  Table  Price
# 31593   0.20  Premium     E     VS2   61.1   59.0    367
# 31597   0.20    Ideal     D     VS2   61.5   57.0    367
# 31596   0.20  Premium     F     VS2   62.6   59.0    367
# 31595   0.20    Ideal     E     VS2   59.7   55.0    367
# 31594   0.20  Premium     E     VS2   59.7   62.0    367
# ...      ...      ...   ...     ...    ...    ...    ...
# 25999   4.01  Premium     J      I1   62.5   62.0  15223
# 25998   4.01  Premium     I      I1   61.0   61.0  15223
# 27130   4.13     Fair     H      I1   64.8   61.0  17329
# 27630   4.50     Fair     J      I1   65.8   58.0  18531
# 27415   5.01     Fair     J      I1   65.5   59.0  18018
#
# [53940 rows x 7 columns]

# %%
df.sort_values(by= ['Carat'] , ascending=False)
# Out:
#        Carat      Cut Color Clarity  Depth  Table  Price
# 27415   5.01     Fair     J      I1   65.5   59.0  18018
# 27630   4.50     Fair     J      I1   65.8   58.0  18531
# 27130   4.13     Fair     H      I1   64.8   61.0  17329
# 25999   4.01  Premium     J      I1   62.5   62.0  15223
# 25998   4.01  Premium     I      I1   61.0   61.0  15223
# ...      ...      ...   ...     ...    ...    ...    ...
# 31592   0.20  Premium     E     VS2   59.0   60.0    367
# 31591   0.20  Premium     E     VS2   59.8   62.0    367
# 31601   0.20  Premium     D     VS2   61.7   60.0    367
# 14      0.20  Premium     E     SI2   60.2   62.0    345
# 31596   0.20  Premium     F     VS2   62.6   59.0    367
#
# [53940 rows x 7 columns]

# %%
df_filtered = df[df['Carat']>=0.3]
df_filtered
# Out:
#        Carat        Cut Color Clarity  Depth  Table  Price
# 4       0.31       Good     J     SI2   63.3   58.0    335
# 10      0.30       Good     J     SI1   64.0   55.0    339
# 13      0.31      Ideal     J     SI2   62.2   54.0    344
# 15      0.32    Premium     E      I1   60.9   58.0    345
# 16      0.30      Ideal     I     SI2   62.0   54.0    348
# ...      ...        ...   ...     ...    ...    ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757
# 53936   0.72       Good     D     SI1   63.1   55.0   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757
#
# [52341 rows x 7 columns]

# %%
lst= [1,3,4,5,7,2,6]
ser= pd.Series(lst)
ser
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    7
# 5    2
# 6    6
# dtype: int64

# %%
df.head()
# Out:
#    Carat      Cut Color Clarity  Depth  Table  Price
# 0   0.23    Ideal     E     SI2   61.5   55.0    326
# 1   0.21  Premium     E     SI1   59.8   61.0    326
# 2   0.23     Good     E     VS1   56.9   65.0    327
# 3   0.29  Premium     I     VS2   62.4   58.0    334
# 4   0.31     Good     J     SI2   63.3   58.0    335

# %%
df = pd.read_csv('diamonds.csv')

# %%
df=df.drop(columns='Unnamed: 0')

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df_xyz = df[(df['x']>5) & (df['y']>5) & (df['z']>5)]

df_xyz
# Out:
#        carat        cut color clarity  depth  table  price     x      y      z
# 11778   1.83       Fair     J      I1   70.0   58.0   5083  7.34   7.28   5.12
# 13002   2.14       Fair     J      I1   69.4   57.0   5405  7.74   7.70   5.36
# 13118   2.15       Fair     J      I1   65.5   57.0   5430  8.01   7.95   5.23
# 13562   1.96       Fair     F      I1   66.6   60.0   5554  7.59   7.56   5.04
# 13757   2.22       Fair     J      I1   66.7   56.0   5607  8.04   8.02   5.36
# ...      ...        ...   ...     ...    ...    ...    ...   ...    ...    ...
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90   7.97   5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50   8.47   5.16
# 48410   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12   5.15  31.80
# 49189   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15  31.80   5.12
# 49905   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01   5.04   5.06
#
# ...

# %%
df_cut= df[(df['cut']== 'Ideal') | (df['cut']=='Premium')]
df_cut
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 11      0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [35342 rows x 10 columns]

# %%
df_cut= df[(df['cut']== 'Ideal') | (df['cut']=='Premium') | (df['cut']=='Fair')]
df_cut
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 8       0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 11      0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [36952 rows x 10 columns]

# %%
df_cut= df[df.cut.isin(['Fair','Ideal','Premium'])]
df_cut
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 8       0.22     Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 11      0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [36952 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
df.apply(lambda row : str(row['carat']) + " " + str(row['cut']),axis=1)
# Out:
# 0           0.23 Ideal
# 1         0.21 Premium
# 2            0.23 Good
# 3         0.29 Premium
# 4            0.31 Good
#              ...
# 53935       0.72 Ideal
# 53936        0.72 Good
# 53937    0.7 Very Good
# 53938     0.86 Premium
# 53939       0.75 Ideal
# Length: 53940, dtype: object

# %%
for i in df.index:
    print(df['carat'][i] , " ", df['cut'][i])
# Out:
# 0.23   Ideal
# 0.21   Premium
# 0.23   Good
# 0.29   Premium
# 0.31   Good
# 0.24   Very Good
# 0.24   Very Good
# 0.26   Very Good
# 0.22   Fair
# 0.23   Very Good
# 0.3   Good
# 0.23   Ideal
# 0.22   Premium
# 0.31   Ideal
# 0.2   Premium
# 0.32   Premium
# 0.3   Ideal
# 0.3   Good
# 0.3   Good
# 0.3   Very Good
# 0.3   Good
# 0.23   Very Good
# 0.23   Very Good
# 0.31   Very Good
# 0.31   Very Good
# 0.23   Very Good
# 0.24   Premium
# 0.3   Very Good
# 0.23   Very Good
# 0.23   Very Good
# 0.23   Very Good
# 0.23   Very Good
# 0.23   Very Good
# 0.23   Very Good
# 0.23   Very Good
# 0.23   Good
# 0.23   Good
# 0.31   Good
# 0.26   Very Good
# 0.33   Ideal
# 0.33   Ideal
# 0.33   Ideal
# 0.26   Good
# 0.26   Good
# 0.32   Good
# 0.29   Premium
# 0.32   Very Good
# 0.32   Good
# 0.25   Very Good
# 0.29   Very Good
# 0.24   Very Good
# 0.23   Ideal
# 0.32   Ideal
# 0.22   Premium
# 0.22   Premium
# 0.3   Ideal
# 0.3   Premium
# 0.3   Very Good
# 0.3   Very Good
# 0.3   Good
# ...

# %%
for index, row in df.iterrows():
    print(row['carat'], row['cut'])
# Out:
# 0.23 Ideal
# 0.21 Premium
# 0.23 Good
# 0.29 Premium
# 0.31 Good
# 0.24 Very Good
# 0.24 Very Good
# 0.26 Very Good
# 0.22 Fair
# 0.23 Very Good
# 0.3 Good
# 0.23 Ideal
# 0.22 Premium
# 0.31 Ideal
# 0.2 Premium
# 0.32 Premium
# 0.3 Ideal
# 0.3 Good
# 0.3 Good
# 0.3 Very Good
# 0.3 Good
# 0.23 Very Good
# 0.23 Very Good
# 0.31 Very Good
# 0.31 Very Good
# 0.23 Very Good
# 0.24 Premium
# 0.3 Very Good
# 0.23 Very Good
# 0.23 Very Good
# 0.23 Very Good
# 0.23 Very Good
# 0.23 Very Good
# 0.23 Very Good
# 0.23 Very Good
# 0.23 Good
# 0.23 Good
# 0.31 Good
# 0.26 Very Good
# 0.33 Ideal
# 0.33 Ideal
# 0.33 Ideal
# 0.26 Good
# 0.26 Good
# 0.32 Good
# 0.29 Premium
# 0.32 Very Good
# 0.32 Good
# 0.25 Very Good
# 0.29 Very Good
# 0.24 Very Good
# 0.23 Ideal
# 0.32 Ideal
# 0.22 Premium
# 0.22 Premium
# 0.3 Ideal
# 0.3 Premium
# 0.3 Very Good
# 0.3 Very Good
# 0.3 Good
# 0.35 Ideal
# 0.3 Premium
# 0.3 Ideal
# 0.3 Ideal
# 0.42 Premium
# 0.28 Ideal
# 0.32 Ideal
# 0.31 Very Good
# 0.31 Premium
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
 df = df.drop(['carat','cut','clarity'],axis=1)

# %%
df
# Out:
#       color  depth  table  price     x     y     z
# 0         E   61.5   55.0    326  3.95  3.98  2.43
# 1         E   59.8   61.0    326  3.89  3.84  2.31
# 2         E   56.9   65.0    327  4.05  4.07  2.31
# 3         I   62.4   58.0    334  4.20  4.23  2.63
# 4         J   63.3   58.0    335  4.34  4.35  2.75
# ...     ...    ...    ...    ...   ...   ...   ...
# 53935     D   60.8   57.0   2757  5.75  5.76  3.50
# 53936     D   63.1   55.0   2757  5.69  5.75  3.61
# 53937     D   62.8   60.0   2757  5.66  5.68  3.56
# 53938     H   61.0   58.0   2757  6.15  6.12  3.74
# 53939     D   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
df = df.drop(['color'],axis=1)

# %%
df
# Out:
#        depth  table  price     x     y     z
# 0       61.5   55.0    326  3.95  3.98  2.43
# 1       59.8   61.0    326  3.89  3.84  2.31
# 2       56.9   65.0    327  4.05  4.07  2.31
# 3       62.4   58.0    334  4.20  4.23  2.63
# 4       63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...   ...   ...   ...
# 53935   60.8   57.0   2757  5.75  5.76  3.50
# 53936   63.1   55.0   2757  5.69  5.75  3.61
# 53937   62.8   60.0   2757  5.66  5.68  3.56
# 53938   61.0   58.0   2757  6.15  6.12  3.74
# 53939   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 6 columns]

# %%
df_new
# Out:
#        carat        cut     x     y     z quality_color
# 0       0.23      Ideal  3.95  3.98  2.43             E
# 1       0.21    Premium  3.89  3.84  2.31             E
# 2       0.23       Good  4.05  4.07  2.31             E
# 3       0.29    Premium  4.20  4.23  2.63             I
# 4       0.31       Good  4.34  4.35  2.75             J
# ...      ...        ...   ...   ...   ...           ...
# 53935   0.72      Ideal  5.75  5.76  3.50             D
# 53936   0.72       Good  5.69  5.75  3.61             D
# 53937   0.70  Very Good  5.66  5.68  3.56             D
# 53938   0.86    Premium  6.15  6.12  3.74             H
# 53939   0.75      Ideal  5.83  5.87  3.64             D
#
# [53940 rows x 6 columns]

# %%
cat = df_new['cut'].unique()

# %%
cat
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
dia = df[df_new['cut'].isin(cat)]

# %%
dia
# Out:
#        depth  table  price     x     y     z
# 0       61.5   55.0    326  3.95  3.98  2.43
# 1       59.8   61.0    326  3.89  3.84  2.31
# 2       56.9   65.0    327  4.05  4.07  2.31
# 3       62.4   58.0    334  4.20  4.23  2.63
# 4       63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...   ...   ...   ...
# 53935   60.8   57.0   2757  5.75  5.76  3.50
# 53936   63.1   55.0   2757  5.69  5.75  3.61
# 53937   62.8   60.0   2757  5.66  5.68  3.56
# 53938   61.0   58.0   2757  6.15  6.12  3.74
# 53939   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 6 columns]

# %%
for i in df.columns:
    print(df[i].mean())
# Out:
# 61.749404894327036
# 57.45718390804598
# 3932.799721913237
# 5.731157211716722
# 5.734525954764553
# 3.5387337782721544

# %%
df.columns
# Out:
# Index(['depth', 'table', 'price', 'x', 'y', 'z'], dtype='object')

# %%
df['price'].min()
# Out:
# 326

# %%
df['price'].max()
# Out:
# 18823

# %%
df['price'].count()
# Out:
# 53940

# %%
df = pd.read_csv('diamonds.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df= df.drop(['Unnamed: 0'],axis=1)

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df = df.drop(['cut','color','clarity'],axis=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x=df['depth'],y=df['price'],data=df)
# Out:
# <Axes: xlabel='depth', ylabel='price'>

# %%
df = pd.read_csv('diamonds.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df= df.drop(['Unnamed: 0'],axis=1)

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df['cut'].nunique()
# Out:
# 5

# %%
pd.crosstab(df['cut'],df['price'])
# Out:
# price      326    327    334    335    336    337    338    339    340    \
# cut
# Fair           0      0      0      0      0      1      0      0      0
# Good           0      1      0      1      0      0      0      1      0
# Ideal          1      0      0      0      0      0      0      0      1
# Premium        1      0      1      0      0      0      0      0      0
# Very Good      0      0      0      0      2      1      1      0      0
#
# price      342    ...  18787  18788  18791  18795  18797  18803  18804  18806  \
# cut               ...
# Fair           0  ...      0      0      0      0      0      0      0      0
# Good           0  ...      0      1      0      0      0      0      0      0
# Ideal          0  ...      1      0      1      0      0      0      1      1
# Premium        1  ...      0      0      1      2      1      0      0      0
# Very Good      0  ...      0      0      0      0      0      1      0      0
#
# price      18818  18823
# ...

# %%
df['cut'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 53940 entries, 0 to 53939
# Series name: cut
# Non-Null Count  Dtype
# --------------  -----
# 53940 non-null  object
# dtypes: object(1)
# memory usage: 421.5+ KB

# %%
df['cut'].describe()
# Out:
# count     53940
# unique        5
# top       Ideal
# freq      21551
# Name: cut, dtype: object

# %%
sns.histplot(x=df['carat'],data=df)
# Out:
# <Axes: xlabel='carat', ylabel='Count'>

# %%
mean_values = df.groupby('cut')[['carat', 'price', 'depth']].mean().plot(kind='bar')

# %%
df.cut.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cut'>

# %%
val = df['cut'].value_counts()

# %%
val
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
cat = df['cut'].unique()

# %%
cat
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
sns.barplot(x=df['cut'].value_counts(),data=df)
# Out:
# <Axes: xlabel='count'>

# %%
data = {
  "myval": [True]
}

df = pd.DataFrame(data)

print(df.bool())
# Out:
# True
# C:\Users\dai.STUDENTSDC\AppData\Local\Temp\ipykernel_8056\3179394954.py:7: FutureWarning: DataFrame.bool is now deprecated and will be removed in future version of pandas
#   print(df.bool())

# %%
df.isnull().head(10)
# Out:
#    myval
# 0  False

# %%
df.columns
# Out:
# Index(['myval'], dtype='object')

# %%
df = pd.read_csv('diamonds.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df = df.drop(['Unnamed: 0'],axis=1)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
for i in df.columns:
    print(i,df[i].isnull().sum())
# Out:
# carat 0
# cut 0
# color 0
# clarity 0
# depth 0
# table 0
# price 0
# x 0
# y 0
# z 0

# %%
df.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.dropna()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.dropna(how='any').shape
# Out:
# (53940, 10)

# %%
df= df.set_index('carat')

# %%
df.loc[0.23]
# Out:
#              cut color clarity  depth  table  price     x     y     z
# carat
# 0.23       Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 0.23        Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 0.23   Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 0.23       Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 0.23   Very Good     E     VS2   63.8   55.0    352  3.85  3.92  2.48
# ...          ...   ...     ...    ...    ...    ...   ...   ...   ...
# 0.23       Ideal     E     VS2   61.8   54.0    548  3.94  3.96  2.44
# 0.23       Ideal     F     VS1   61.4   55.0    548  3.96  3.99  2.44
# 0.23       Ideal     F     VS1   61.1   56.0    548  3.97  3.99  2.43
# 0.23   Very Good     D    VVS2   58.9   60.0    549  4.03  3.95  2.35
# 0.23     Premium     G    VVS2   58.1   59.0    550  4.09  4.03  2.36
#
# [293 rows x 9 columns]

# %%
df
# Out:
#              cut color clarity  depth  table  price     x     y     z
# carat
# 0.23       Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 0.21     Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0.23        Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 0.29     Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 0.31        Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...          ...   ...     ...    ...    ...    ...   ...   ...   ...
# 0.72       Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 0.72        Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 0.70   Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 0.86     Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 0.75       Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %%
df= df.reset_index()

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
df['cut'].value_counts().sort_values()
# Out:
# cut
# Fair          1610
# Good          4906
# Very Good    12082
# Premium      13791
# Ideal        21551
# Name: count, dtype: int64

# %%
df['cut'].value_counts().sort_index()
# Out:
# cut
# Fair          1610
# Good          4906
# Ideal        21551
# Premium      13791
# Very Good    12082
# Name: count, dtype: int64

# %%
df.x*df.y*df.z
# Out:
# 0         38.202030
# 1         34.505856
# 2         38.076885
# 3         46.724580
# 4         51.917250
#             ...
# 53935    115.920000
# 53936    118.110175
# 53937    114.449728
# 53938    140.766120
# 53939    124.568444
# Length: 53940, dtype: float64

# %%
pd.concat([df,df['color']],axis=1)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       color
# 0         E
# 1         E
# ...

# %%
# Out:
# carat         0.21
# cut        Premium
# color            E
# clarity        SI1
# depth         59.8
# table         61.0
# price          326
# x             3.89
# y             3.84
# z             2.31
# Name: 1, dtype: object

# %%
df.iloc[0:3]
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
df.loc[[0,5,7]]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 11.0 MB

# %%
df.sample()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 43737   0.51  Very Good     E     SI1   61.3   54.0   1438  5.13  5.18  3.16

# %%
df_75= df.sample(frac=0.75)

# %%
df_75
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 27640   2.09    Premium     H     SI1   61.1   56.0  18559  8.30  8.23  5.05
# 4045    0.92    Premium     I     SI1   60.7   58.0   3529  6.30  6.25  3.81
# 32133   0.41      Ideal     I    VVS1   62.3   53.0    785  4.77  4.79  2.98
# 28785   0.37  Very Good     D     SI1   62.2   58.0    681  4.58  4.62  2.86
# 17269   1.51  Very Good     I     SI2   63.2   58.0   6914  7.31  7.27  4.61
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 21245   1.50       Good     H     SI1   61.0   59.0   9394  7.31  7.39  4.48
# 49670   0.70      Ideal     H     SI2   59.9   57.0   2142  5.77  5.74  3.45
# 47272   0.50      Ideal     H      IF   61.1   58.0   1844  5.10  5.14  3.13
# 30101   0.32    Premium     H     VS1   61.3   60.0    720  4.38  4.33  2.67
# 52415   0.70    Premium     G     VS1   62.6   60.0   2512  5.58  5.66  3.52
#
# [40455 rows x 10 columns]

# %%
df[df['color'].duplicated()]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 8       0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53933 rows x 10 columns]

# %%
df[df['color'].duplicated()]
# Out:
# carat                                                43039.1
# cut        PremiumGoodVery GoodVery GoodFairVery GoodGood...
# color      EEJIEHJJJEEIJJJIEHJJIJFFFEEDFEHDIIJDDHFHHEHFGI...
# clarity    SI1VS1VVS2VVS1VS2VS1SI1VS1SI2SI2I1SI2SI1SI1SI1...
# depth                                              3330332.5
# table                                              3098834.5
# price                                              212132832
# x                                                  309110.25
# y                                                  309291.84
# z                                                  190861.82
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 146
